# %% [markdown]
# # **Task 3: Python Programming Assignment Data Processing and Analysis**

# %% [markdown]
# ## Problem Statement 1: Employee Performance Bonus Eligibility
# **Description:**
# A company evaluates employee performance scores at the end of the year. You are given a dictionary containing employee names and their performance scores.
#
# **Requirements:**
# Identify the highest performance score.
# Handle ties if multiple employees have the same highest score.
# Display all employees eligible for the top performance bonus.
#
# **Input:**
# employees = {
# "Ravi": 92,
# "Anita": 88,
# "Kiran": 92,
# "Suresh": 85
# }
#
# **Expected Output:**
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %%
#dictionary storing employee names and performance scores
employees = {
    "Ravi": 92,
    "Anita": 88,
    "Kiran": 92,
    "Suresh": 85
}

#to find highest performance score
max_score = max(employees.values())

#list to store employees having highest score
top_performers = []

#to check each employee's score
for i in employees:
    if employees[i] == max_score:
        top_performers.append(i)

#to display eligible employees for bonus
print("Top Performers Eligible for Bonus:", ", ".join(top_performers), "(Score:", max_score, ")")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92 )

# %% [markdown]
# ## Problem Statement 2: Search Query Keyword Analysis
# **Description:**
# An e-commerce website stores customer search queries. You are given a search query sentence entered by a user.
#
# **Requirements:**
# Convert the input to lowercase.
# Ignore common punctuation.
# Count the frequency of each keyword.
# Display only keywords searched more than once.
#
# **Input:**
# "Buy mobile phone buy phone online"
#
# **Expected Output:**
# {'buy': 2, 'phone': 2}

# %%
#to search query input
query = "Buy mobile phone buy phone online"

#to convert text to lowercase handling case sensitivity
query = query.lower()

#to split sentence into individual words
words = query.split()

#dictionary to store word frequency
count = {}

#to count occurrences of each word
for i in words:
    if i in count:
        count[i] += 1
    else:
        count[i] = 1

#to store only repeated words
result = {}

for word in count:
    if count[word] > 1:
        result[word] = count[word]

#to display repeated keywords
print(result)
# Out:
# {'buy': 2, 'phone': 2}

# %% [markdown]
# ## Problem Statement 3: Sensor Data Validation
# **Description:**
# A factory collects sensor readings every hour. Each reading is stored in a list where the index represents the hour and the value represents the sensor reading.
#
# **Requirements:**
# Identify readings that are even numbers (valid readings).
# Store them as (hour_index, reading_value) pairs.
# Ignore odd readings (invalid readings).
#
# **Input:**
# sensor_readings = [3, 4, 7, 8, 10, 12, 5]
#
# **Expected Output:**
# Valid Sensor Readings (Hour, Value):
#
#                [(1, 4), (3, 8), (4, 10), (5, 12)]

# %%
#list of hourly sensor readings
sensor = [3, 4, 7, 8, 10, 12, 5]

#list to store valid (even) readings
valid = []

#to check each reading
for i in range(len(sensor)):
    # Even values are considered valid
    if sensor[i] % 2 == 0:
        valid.append((i, sensor[i]))

#to display valid readings with hour index
print("Valid Sensor Readings (Hour, Value):")
print(valid)
# Out:
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# ## Problem Statement 4: Email Domain Usage Analysis
# **Description:**
# A company wants to analyze which email providers its users are using. You are given a list of employee email IDs.
#
# **Requirements:**
# Count how many users belong to each email domain.
# Calculate the percentage usage of each domain.
#
# **Input:**
# emails = [
# "ravi@gmail.com",
# "anita@yahoo.com",
# "kiran@gmail.com",
# "suresh@gmail.com",
# "meena@yahoo.com"
# ]
#
# **Expected Output:**
# gmail.com: 60%
#
#                yahoo.com: 40%

# %%
#list of email addresses
emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
]

#dictionary to store domain frequency
domain_count = {}

#extract and count email domains
for i in emails:
    domain = i.split("@")[1]
    if domain in domain_count:
        domain_count[domain] += 1
    else:
        domain_count[domain] = 1

#total number of emails
total = len(emails)

#to calculate and display percentage usage
for i in domain_count:
    percentage = (domain_count[i] * 100) // total
    print(i + ":", str(percentage) + "%")
# Out:
# gmail.com: 60%
# yahoo.com: 40%

# %% [markdown]
# ## Problem Statement 5: Sales Spike Detection
# **Description:**
# A retail company tracks daily sales. Sudden spikes in sales may indicate promotions or unusual activity.
#
# **Requirements:**
# Calculate the average daily sales.
# Detect days where sales are more than 30% above average.
# Display the day number and sale value.
#
# **Input:**
# sales = [1200, 1500, 900, 2200, 1400, 3000]
#
# **Expected Output:**
# Day 6: 3000

# %%
#given sales data
sales = [1200, 1500, 900, 2200, 1400, 3000]

#to calculate average sales
average = sum(sales) / len(sales)

#define spike limit more than 30% above average
limit = average * 1.3

#to check each day's sales
for i in range(len(sales)):
    if sales[i] > limit:
       #displaying result
       print("Day", i + 1, ":", sales[i])
# Out:
# Day 6 : 3000

# %% [markdown]
# ## Problem Statement 6: Duplicate User ID Detection
# **Description:**
# A system stores user IDs during registration. Duplicate IDs can cause data integrity issues.
#
# **Requirements:**
# Identify duplicate user IDs.
# Display how many times each duplicate appears.
#
# **Input:**
# user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]
#
# **Expected Output:**
# user1 → 3 times
#
#                user3 → 2 times

# %%
#list of registered user IDs
userid = ["user1", "user2", "user1", "user3", "user1", "user3"]

#dictionary to store frequency of each user ID
count = {}

#to count occurrences of each user ID
for i in userid:
    if i in count:
        count[i] += 1
    else:
        count[i] = 1

#to display only duplicate user IDs
for i in count:
    if count[i] > 1:
        print(i, "→", count[i], "times")
# Out:
# user1 → 3 times
# user3 → 2 times
